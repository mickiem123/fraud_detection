# %%
import pandas as pd
import numpy as np
df = pd.read_excel(rf"C:\Users\thuhi\Downloads\rating sheet.xlsx",sheet_name="Information table")
df.drop(axis=0,index=0,inplace=True)
df
# Out:
#                   Name Mã cổ phiếu Sàn chứng khoán    Year  Have_Website  \
# 1    CTCP Dược Danapha         DAN           UPCoM  2024.0           1.0
# 2    CTCP Dược Danapha         DAN           UPCoM  2023.0           1.0
# 3    CTCP Dược Danapha         DAN           UPCoM  2022.0           1.0
# 4    CTCP Dược Danapha         DAN           UPCoM  2021.0           1.0
# 5    CTCP Dược Danapha         DAN           UPCoM  2019.0           1.0
# ..                 ...         ...             ...     ...           ...
# 202      CTCP Đồng Tâm     DongTam             OTC  2017.0           1.0
# 203      CTCP Đồng Tâm     DongTam             OTC  2018.0           1.0
# 204      CTCP Đồng Tâm     DongTam             OTC  2019.0           1.0
# 205      CTCP Đồng Tâm     DongTam             OTC  2020.0           1.0
# 206      CTCP Đồng Tâm     DongTam             OTC  2021.0           1.0
#
#      Post Annual Report  Have sustainability section in annual report  \
# ...

# %%
df_trans = df.drop(columns=["Financial indicators","Corporation size"])
df_trans.isna().sum()
# Out:
# Name                                             0
# Mã cổ phiếu                                      0
# Sàn chứng khoán                                  0
# Year                                            10
# Have_Website                                     1
# Post Annual Report                               3
# Have sustainability section in annual report    23
# Post separate Sustainability Report             18
# Industry_Group                                  52
# GHG emissions measurement                       11
# Energy resource management                      11
# Renewable energy adoption                       11
# Raw material management                         11
#  Water resource management                      11
# Net Zero Alignment                              11
# Environmental policy investment                 11
# Community Development Programs                  11
# Employee Welfare and Safety                     11
# ...

# %%
# Out:
# Name                                             0
# Mã cổ phiếu                                      0
# Sàn chứng khoán                                  0
# Year                                            10
# Have_Website                                     1
# Post Annual Report                               3
# Have sustainability section in annual report    23
# Post separate Sustainability Report             18
# Industry_Group                                  52
# GHG emissions measurement                       11
# Energy resource management                      11
# Renewable energy adoption                       11
# Raw material management                         11
#  Water resource management                      11
# Net Zero Alignment                              11
# Environmental policy investment                 11
# Community Development Programs                  11
# Employee Welfare and Safety                     11
# ...
